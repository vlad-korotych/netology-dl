# %%
import torch
import torch.nn.functional as F
import pytorch_lightning as pl
from collections import OrderedDict
from torch.utils.data import DataLoader, random_split
import torchvision as tv
from pytorch_lightning.callbacks import EarlyStopping
import optuna
from optuna.integration import PyTorchLightningPruningCallback
import math
import pandas as pd

# %%
class FashionMNIST(pl.LightningModule):
    def __init__(self, trial: optuna.trial.Trial):
        super(FashionMNIST, self).__init__()
        self.BATCH_SIZE = 256
        self.INPUT_FEATURES = 28*28
        self.OUTPUT_FEATURES = 10
        
        layers = []
        layers.append(('flatten', torch.nn.Flatten()))
        
        # параметры модели
        n_layers = trial.suggest_int("n_layers", 1, 10) # количество скрытых слоев
        max_features = trial.suggest_int("max_features", 0.5 * self.INPUT_FEATURES, 2 * self.INPUT_FEATURES) # количество нейронов в первом скрытом слое
        activaion = trial.suggest_categorical("activation", ['ReLU', 'RReLU', 'LeakyReLU']) # функция активации
        regul = trial.suggest_categorical('regularization', ['batchnorm', 'dropout']) # регуляризация
        self.optimizer = trial.suggest_categorical('optimizer', ['SGD', 'Adam', 'RMSprop']) # Оптимизатор
        self.lr = trial.suggest_loguniform('learning_rate', 0.005, 0.5) # Learning rate
        
        # Архитектура сети:
        #    сеть состоит из n_layers скрытых слоев
        #    первый слой стостоит из max_features нейронов
        #    далее, количество нейронов линейно убывает до количества выходов
        
        input_features = self.INPUT_FEATURES
        delta_features = math.floor((max_features - self.OUTPUT_FEATURES) / n_layers)
        for i in range(1, n_layers+1): 
            if i == 1:
                in_features = self.INPUT_FEATURES
                out_features = max_features
            elif i == n_layers:
                in_features = prev_features
                out_features = self.OUTPUT_FEATURES
            else:
                in_features = prev_features
                out_features = prev_features - delta_features
            
            if regul == 'batchnorm':
                layers.append((f'batchnorm{i}', torch.nn.BatchNorm1d(in_features)))
            elif regul == 'dropout':
                layers.append((f'dropout{i}', torch.nn.Dropout()))
            else:
                raise ValueError
            
            layers.append((f'lin{i}', torch.nn.Linear(in_features, out_features)))
            prev_features = out_features
            
            if i != n_layers:
                if activaion == 'ReLU':
                    layers.append((f'ReLU{i}', torch.nn.ReLU()))
                elif activaion == 'RReLU':
                    layers.append((f'RReLU{i}', torch.nn.RReLU()))
                elif activaion == 'LeakyReLU':
                    layers.append((f'LeakyReLU{i}', torch.nn.LeakyReLU()))
                else:
                    raise ValueError
                    
        self.model = torch.nn.Sequential(OrderedDict(layers))
        

    def forward(self, x):
        return self.model(x)
    
    def configure_optimizers(self):
        if self.optimizer == 'SGD':
            opt = torch.optim.SGD(self.parameters(), lr=self.lr)
        elif self.optimizer == 'Adam':
            opt = torch.optim.Adam(self.parameters(), lr=self.lr)
        elif self.optimizer == 'RMSprop':
            opt = torch.optim.RMSprop(self.parameters(), lr=self.lr)
        
        return opt

    def cross_entropy_loss(self, logits, labels):
        loss = torch.nn.CrossEntropyLoss()
        return loss(logits, labels)
    
    def training_step(self, batch, batch_idx):
        data, target = batch
        output = self.forward(data)
        loss = self.cross_entropy_loss(output, target)
        logs = {'loss': loss}
        return {'loss': loss, 'log': logs}
    
    def validation_step(self, batch, batch_idx):
        data, target = batch
        output = self.forward(data)
        loss = self.cross_entropy_loss(output, target)
        pred = output.argmax(dim=1, keepdim=True)
        correct = pred.eq(target.view_as(pred)).sum().item()
        accuracy = correct / data.size(0)
        
        return {'val_loss': loss, "accuracy": accuracy}

    def validation_epoch_end(self, outputs):
        avg_loss = torch.stack([x['val_loss'] for x in outputs]).mean()
        accuracy = sum(x["accuracy"] for x in outputs) / len(outputs)
        self.val_accuracy = accuracy
        logs = {'val_loss': avg_loss, 'accuracy': accuracy}
        return {'avg_val_loss': avg_loss, 'log': logs}
    
    def test_step(self, batch, batch_nb):
        data, target = batch
        output = self.forward(data)
        loss = self.cross_entropy_loss(output, target)
        pred = output.argmax(dim=1, keepdim=True)
        correct = pred.eq(target.view_as(pred)).sum().item()
        accuracy = correct / data.size(0)
        
        return {'test_loss': loss, 'test_accuracy': accuracy}
    
    def test_epoch_end(self, outputs):
        avg_loss = torch.stack([x['test_loss'] for x in outputs]).mean()
        accuracy = sum(x["test_accuracy"] for x in outputs) / len(outputs)
        self.test_accuracy = accuracy
        
        logs = {'test_loss': avg_loss, 'test_accuracy': accuracy}
        return {'avg_test_loss': avg_loss, 'log': logs, 'progress_bar': logs}
    
    def prepare_data(self):
        self.train_set, self.val_set = random_split(tv.datasets.FashionMNIST('../..', train=True, download=True, transform=tv.transforms.ToTensor()), [55000, 5000])
        self.test_set = tv.datasets.FashionMNIST('../..', train=False, download=True, transform=tv.transforms.ToTensor())
    
    def train_dataloader(self):
        return DataLoader(self.train_set, batch_size=self.BATCH_SIZE, shuffle=True)
    
    def val_dataloader(self):
        return DataLoader(self.val_set, batch_size=self.BATCH_SIZE)
    
    def test_dataloader(self):
        return DataLoader(self.test_set, batch_size=self.BATCH_SIZE)

# %%
MIN_ACCURACY = 0.88

# %%
def objective(trial: optuna.trial.Trial):
    clf = FashionMNIST(trial)
    trainer = pl.Trainer(
        gpus=[0],
        max_epochs=30,
        early_stop_callback=True
    )
    trainer.fit(clf)
    
    trainer.test()
    
    global MIN_ACCURACY
    if clf.test_accuracy > MIN_ACCURACY:
        trainer.save_checkpoint(f'./models/{trial.number}_{clf.test_accuracy:.2}.ckpt')
        MIN_ACCURACY = clf.test_accuracy
    
    return clf.val_accuracy

# %%
study = optuna.create_study(
    direction="maximize",
    study_name='FashionMNIST',
    storage='sqlite:///FashionMNIST.db',
    load_if_exists=True
)
# Out:
# [I 2020-04-07 23:02:09,769] Using an existing study with name 'FashionMNIST' instead of creating a new one.

# %%
study.optimize(objective, timeout=9*60*60)

# %%
pd.set_option('display.max_rows', None)

# %%
df = study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))

# %%
df.sort_values(by='value', ascending=False)
# Out:
#      number     value params_activation  params_learning_rate  \
# 640     640  0.908720              ReLU              0.005415
# 689     689  0.905044              ReLU              0.007355
# 588     588  0.904963              ReLU              0.005525
# 740     740  0.904745              ReLU              0.005964
# 659     659  0.904435              ReLU              0.006143
# 599     599  0.903941              ReLU              0.017831
# 681     681  0.903228              ReLU              0.006338
# 189     189  0.902642         LeakyReLU              0.005066
# 574     574  0.902252              ReLU              0.005006
# 42       42  0.902252              ReLU              0.005034
# 707     707  0.902229              ReLU              0.006307
# 650     650  0.901907              ReLU              0.005022
# 605     605  0.901861              ReLU              0.018405
# 670     670  0.901838              ReLU              0.006655
# 508     508  0.901620         LeakyReLU              0.005858
# 87       87  0.901574         LeakyReLU              0.044122
# 662     662  0.901540              ReLU              0.006128
# 646     646  0.901425              ReLU              0.005463
# 369     369  0.901183              ReLU              0.005026
# 706     706  0.900931              ReLU              0.006175
# 753     753  0.900931              ReLU              0.005878
# 688     688  0.900862              ReLU              0.006052
# 402     402  0.900816         LeakyReLU              0.211057
# 204     204  0.900781              ReLU              0.007107
# 727     727  0.900712              ReLU              0.005052
# 99       99  0.900517         LeakyReLU              0.005489
# 580     580  0.900494              ReLU              0.005845
# 32       32  0.900494              ReLU              0.008395
# 725     725  0.900448              ReLU              0.005888
# 179     179  0.900437              ReLU              0.007595
# 265     265  0.900402              ReLU              0.133653
# 377     377  0.900322         LeakyReLU              0.146448
# 138     138  0.900253             RReLU              0.005093
# 643     643  0.900218              ReLU              0.005472
# 260     260  0.900046              ReLU              0.005804
# 291     291  0.899989         LeakyReLU              0.020818
# 732     732  0.899931              ReLU              0.005775
# 509     509  0.899885             RReLU              0.005692
# 288     288  0.899862         LeakyReLU              0.015571
# 582     582  0.899862              ReLU              0.005015
# 463     463  0.899839         LeakyReLU              0.006656
# 24       24  0.899713              ReLU              0.006136
# 22       22  0.899586              ReLU              0.015140
# 523     523  0.899563         LeakyReLU              0.007007
# 735     735  0.899540              ReLU              0.030128
# 352     352  0.899517         LeakyReLU              0.006525
# 113     113  0.899449              ReLU              0.006992
# 524     524  0.899357         LeakyReLU              0.006372
# 238     238  0.899276         LeakyReLU              0.082038
# 235     235  0.899276         LeakyReLU              0.070668
# 658     658  0.899253              ReLU              0.005031
# 338     338  0.899230              ReLU              0.007477
# 558     558  0.899173              ReLU              0.257558
# 115     115  0.899150              ReLU              0.006225
# 692     692  0.899092              ReLU              0.007439
# 187     187  0.899035         LeakyReLU              0.006141
# 592     592  0.898977              ReLU              0.005538
# 314     314  0.898955         LeakyReLU              0.095477
# 514     514  0.898932             RReLU              0.005084
# 661     661  0.898909              ReLU              0.005023
# 585     585  0.898886              ReLU              0.005011
# 18       18  0.898863              ReLU              0.194543
# 664     664  0.898863              ReLU              0.006139
# 93       93  0.898759         LeakyReLU              0.007576
# 263     263  0.898644              ReLU              0.005991
# 591     591  0.898633              ReLU              0.005005
# 455     455  0.898633         LeakyReLU              0.053423
# 66       66  0.898541              ReLU              0.009271
# 245     245  0.898541         LeakyReLU              0.006686
# 221     221  0.898518         LeakyReLU              0.006777
# 542     542  0.898483         LeakyReLU              0.006327
# 686     686  0.898392              ReLU              0.006522
# 71       71  0.898334              ReLU              0.006060
# 158     158  0.898334              ReLU              0.022253
# 175     175  0.898323             RReLU              0.007969
# 691     691  0.898323              ReLU              0.007645
# 281     281  0.898323              ReLU              0.006186
# 319     319  0.898311              ReLU              0.082878
# 653     653  0.898288              ReLU              0.005630
# 363     363  0.898254              ReLU              0.024407
# 305     305  0.898219         LeakyReLU              0.006179
# 757     757  0.898208              ReLU              0.005013
# 597     597  0.898196              ReLU              0.005828
# 230     230  0.898150         LeakyReLU              0.008118
# 356     356  0.898081         LeakyReLU              0.006380
# 178     178  0.898081              ReLU              0.007429
# 748     748  0.898070              ReLU              0.006285
# 584     584  0.898024              ReLU              0.005028
# 456     456  0.898001              ReLU              0.006838
# 495     495  0.897978             RReLU              0.006846
# 680     680  0.897978              ReLU              0.005935
# 480     480  0.897955         LeakyReLU              0.005489
# 750     750  0.897840              ReLU              0.005863
# 65       65  0.897829              ReLU              0.009033
# 663     663  0.897806              ReLU              0.006298
# 647     647  0.897737              ReLU              0.005073
# 751     751  0.897714              ReLU              0.005483
# 56       56  0.897714              ReLU              0.008865
# 467     467  0.897702              ReLU              0.032470
# 633     633  0.897656              ReLU              0.224424
# 192     192  0.897633         LeakyReLU              0.006818
# 49       49  0.897610              ReLU              0.354844
# 561     561  0.897587              ReLU              0.010663
# 141     141  0.897564             RReLU              0.006356
# 349     349  0.897518              ReLU              0.071552
# 452     452  0.897507             RReLU              0.008887
# 630     630  0.897495              ReLU              0.005041
# 586     586  0.897461              ReLU              0.005496
# 252     252  0.897392         LeakyReLU              0.006567
# 755     755  0.897323              ReLU              0.007019
# 308     308  0.897289         LeakyReLU              0.041611
# 407     407  0.897220         LeakyReLU              0.005013
# 712     712  0.897197              ReLU              0.006390
# 719     719  0.897197              ReLU              0.006096
# 632     632  0.897174              ReLU              0.005984
# 723     723  0.897151              ReLU              0.005367
# 216     216  0.897151              ReLU              0.008087
# 702     702  0.897151              ReLU              0.006001
# 159     159  0.897151              ReLU              0.021843
# 718     718  0.897128              ReLU              0.005407
# 701     701  0.897128              ReLU              0.006388
# 95       95  0.897105         LeakyReLU              0.025331
# 499     499  0.897047              ReLU              0.005932
# 297     297  0.897024         LeakyReLU              0.016307
# 251     251  0.897001         LeakyReLU              0.005613
# 498     498  0.897001         LeakyReLU              0.005015
# 451     451  0.896978              ReLU              0.007232
# 185     185  0.896978              ReLU              0.008804
# 38       38  0.896978              ReLU              0.009988
# 506     506  0.896955         LeakyReLU              0.029254
# 232     232  0.896932         LeakyReLU              0.007366
# 122     122  0.896921              ReLU              0.008341
# 749     749  0.896921              ReLU              0.005015
# 728     728  0.896921              ReLU              0.005061
# 152     152  0.896909              ReLU              0.314551
# 112     112  0.896875              ReLU              0.009216
# 608     608  0.896852              ReLU              0.022036
# 215     215  0.896760              ReLU              0.008871
# 114     114  0.896760              ReLU              0.006895
# 578     578  0.896726              ReLU              0.009265
# 575     575  0.896703              ReLU              0.005039
# 690     690  0.896691              ReLU              0.008335
# 742     742  0.896680              ReLU              0.005545
# 528     528  0.896588         LeakyReLU              0.005780
# 182     182  0.896542              ReLU              0.008398
# 708     708  0.896530              ReLU              0.006030
# 321     321  0.896530              ReLU              0.076433
# 515     515  0.896484             RReLU              0.005900
# 560     560  0.896461         LeakyReLU              0.005905
# 625     625  0.896438              ReLU              0.005836
# 744     744  0.896415              ReLU              0.005025
# 155     155  0.896392              ReLU              0.005305
# 649     649  0.896369              ReLU              0.005366
# 30       30  0.896369              ReLU              0.008068
# 331     331  0.896335              ReLU              0.007860
# 170     170  0.896278         LeakyReLU              0.009535
# 734     734  0.896243              ReLU              0.005478
# 474     474  0.896243         LeakyReLU              0.045056
# 194     194  0.896232         LeakyReLU              0.006346
# 51       51  0.896197              ReLU              0.355174
# 350     350  0.896094              ReLU              0.010869
# 596     596  0.896094              ReLU              0.005020
# 726     726  0.896082              ReLU              0.006364
# 581     581  0.896025              ReLU              0.005456
# 145     145  0.896013              ReLU              0.006129
# 234     234  0.896002         LeakyReLU              0.007047
# 346     346  0.895910         LeakyReLU              0.006217
# 512     512  0.895875             RReLU              0.005392
# 430     430  0.895830              ReLU              0.013889
# 279     279  0.895807              ReLU              0.006760
# 761     761  0.895807              ReLU              0.007390
# 685     685  0.895784              ReLU              0.007132
# 743     743  0.895715              ReLU              0.006105
# 644     644  0.895680              ReLU              0.005017
# 604     604  0.895680              ReLU              0.018518
# 693     693  0.895611              ReLU              0.006965
# 337     337  0.895611         LeakyReLU              0.006962
# 306     306  0.895600         LeakyReLU              0.023523
# 466     466  0.895588             RReLU              0.007320
# 534     534  0.895565         LeakyReLU              0.005388
# 517     517  0.895554             RReLU              0.005640
# 529     529  0.895531         LeakyReLU              0.006253
# 489     489  0.895485         LeakyReLU              0.005439
# 519     519  0.895416             RReLU              0.008830
# 213     213  0.895416              ReLU              0.005019
# 651     651  0.895393              ReLU              0.005653
# 23       23  0.895381              ReLU              0.010239
# 131     131  0.895370              ReLU              0.008970
# 525     525  0.895347         LeakyReLU              0.006255
# 672     672  0.895324              ReLU              0.006730
# 494     494  0.895324              ReLU              0.234593
# 660     660  0.895267              ReLU              0.006143
# 437     437  0.895244         LeakyReLU              0.006329
# 677     677  0.895244              ReLU              0.007096
# 737     737  0.895221              ReLU              0.006310
# 86       86  0.895198              ReLU              0.006565
# 461     461  0.895175         LeakyReLU              0.005764
# 665     665  0.895140              ReLU              0.005448
# 240     240  0.895129         LeakyReLU              0.074734
# 607     607  0.895117              ReLU              0.017644
# 621     621  0.895106              ReLU              0.005827
# 257     257  0.895071         LeakyReLU              0.005035
# 720     720  0.895060              ReLU              0.005642
# 747     747  0.894933              ReLU              0.046889
# 710     710  0.894922              ReLU              0.005896
# 144     144  0.894910              ReLU              0.009439
# 239     239  0.894899         LeakyReLU              0.050155
# 382     382  0.894853              ReLU              0.163189
# 562     562  0.894853         LeakyReLU              0.005006
# 593     593  0.894841              ReLU              0.005829
# 618     618  0.894830              ReLU              0.005329
# 762     762  0.894784              ReLU              0.005469
# 741     741  0.894784              ReLU              0.005858
# 713     713  0.894773              ReLU              0.005492
# 379     379  0.894727              ReLU              0.015301
# 551     551  0.894704         LeakyReLU              0.014289
# 674     674  0.894704              ReLU              0.006470
# 554     554  0.894681         LeakyReLU              0.025466
# 188     188  0.894658         LeakyReLU              0.006092
# 460     460  0.894635              ReLU              0.005024
# 92       92  0.894635         LeakyReLU              0.037942
# 492     492  0.894635              ReLU              0.006043
# 393     393  0.894612              ReLU              0.018850
# 648     648  0.894600              ReLU              0.005558
# 603     603  0.894589              ReLU              0.015349
# 615     615  0.894566              ReLU              0.021989
# 303     303  0.894554         LeakyReLU              0.006744
# 752     752  0.894531              ReLU              0.006589
# 406     406  0.894508         LeakyReLU              0.006005
# 273     273  0.894508              ReLU              0.223189
# 639     639  0.894508              ReLU              0.005001
# 628     628  0.894462              ReLU              0.005057
# 101     101  0.894439         LeakyReLU              0.005547
# 717     717  0.894393              ReLU              0.005002
# 449     449  0.894370              ReLU              0.007558
# 110     110  0.894359              ReLU              0.008338
# 673     673  0.894347              ReLU              0.006509
# 133     133  0.894336              ReLU              0.009956
# 205     205  0.894290              ReLU              0.007119
# 566     566  0.894244              ReLU              0.008115
# 73       73  0.894210              ReLU              0.006101
# 424     424  0.894118              ReLU              0.008078
# 84       84  0.894095              ReLU              0.005713
# 151     151  0.894003              ReLU              0.392305
# 746     746  0.894003              ReLU              0.005038
# 368     368  0.894003         LeakyReLU              0.008310
# 458     458  0.893991              ReLU              0.014914
# 631     631  0.893957              ReLU              0.005003
# 214     214  0.893945              ReLU              0.034483
# 695     695  0.893922              ReLU              0.009216
# 287     287  0.893922              ReLU              0.005016
# 536     536  0.893899         LeakyReLU              0.007954
# 436     436  0.893899              ReLU              0.005418
# 601     601  0.893876              ReLU              0.016297
# 156     156  0.893830              ReLU              0.005767
# 552     552  0.893739         LeakyReLU              0.006673
# 683     683  0.893727              ReLU              0.006431
# 367     367  0.893704              ReLU              0.006467
# 207     207  0.893681         LeakyReLU              0.007792
# 81       81  0.893681              ReLU              0.008887
# 173     173  0.893658             RReLU              0.006507
# 694     694  0.893658              ReLU              0.008302
# 253     253  0.893647         LeakyReLU              0.006090
# 697     697  0.893624              ReLU              0.007389
# 504     504  0.893612         LeakyReLU              0.005357
# 85       85  0.893612              ReLU              0.005099
# 565     565  0.893532         LeakyReLU              0.005599
# 478     478  0.893474         LeakyReLU              0.008984
# 696     696  0.893463              ReLU              0.006855
# 595     595  0.893440              ReLU              0.013005
# 624     624  0.893440              ReLU              0.020670
# 261     261  0.893428              ReLU              0.005432
# 590     590  0.893417              ReLU              0.005474
# 19       19  0.893371              ReLU              0.034105
# 408     408  0.893371         LeakyReLU              0.087371
# 118     118  0.893359              ReLU              0.005570
# 320     320  0.893336         LeakyReLU              0.142977
# 78       78  0.893336              ReLU              0.025959
# 510     510  0.893313             RReLU              0.005399
# 105     105  0.893313         LeakyReLU              0.021776
# 340     340  0.893256              ReLU              0.008319
# 361     361  0.893244              ReLU              0.005796
# 193     193  0.893233         LeakyReLU              0.005739
# 413     413  0.893187         LeakyReLU              0.216375
# 293     293  0.893164         LeakyReLU              0.020734
# 522     522  0.893153         LeakyReLU              0.011846
# 572     572  0.893118         LeakyReLU              0.005411
# 453     453  0.893095         LeakyReLU              0.006057
# 376     376  0.893072              ReLU              0.007534
# 231     231  0.893072         LeakyReLU              0.008108
# 657     657  0.893072              ReLU              0.006021
# 132     132  0.893072              ReLU              0.007807
# 311     311  0.893026         LeakyReLU              0.005471
# 527     527  0.893015         LeakyReLU              0.006836
# 74       74  0.892992              ReLU              0.007398
# 397     397  0.892980         LeakyReLU              0.092090
# 715     715  0.892946              ReLU              0.005859
# 441     441  0.892934              ReLU              0.006744
# 212     212  0.892900              ReLU              0.007178
# 62       62  0.892854              ReLU              0.005094
# 415     415  0.892831         LeakyReLU              0.035240
# 598     598  0.892819              ReLU              0.005981
# 196     196  0.892796         LeakyReLU              0.007104
# 678     678  0.892773              ReLU              0.005001
# 103     103  0.892750         LeakyReLU              0.007988
# 446     446  0.892705         LeakyReLU              0.006414
# 620     620  0.892705              ReLU              0.005362
# 172     172  0.892659             RReLU              0.007319
# 704     704  0.892659              ReLU              0.007585
# 721     721  0.892659              ReLU              0.006483
# 21       21  0.892624              ReLU              0.016930
# 423     423  0.892578             RReLU              0.005500
# 473     473  0.892578              ReLU              0.007326
# 722     722  0.892578              ReLU              0.007206
# 614     614  0.892544              ReLU              0.023828
# 403     403  0.892509         LeakyReLU              0.067341
# 434     434  0.892486              ReLU              0.017066
# 513     513  0.892486             RReLU              0.009752
# 541     541  0.892463         LeakyReLU              0.005019
# 183     183  0.892452              ReLU              0.007033
# 254     254  0.892452             RReLU              0.090372
# 82       82  0.892440              ReLU              0.008408
# 121     121  0.892440              ReLU              0.006280
# 611     611  0.892429              ReLU              0.020377
# 435     435  0.892383         LeakyReLU              0.073319
# 645     645  0.892337              ReLU              0.005367
# 366     366  0.892314              ReLU              0.007282
# 754     754  0.892314              ReLU              0.006238
# 626     626  0.892314              ReLU              0.018113
# 307     307  0.892314         LeakyReLU              0.158012
# 416     416  0.892291             RReLU              0.020709
# 589     589  0.892233              ReLU              0.005033
# 668     668  0.892233              ReLU              0.006038
# 401     401  0.892233              ReLU              0.265716
# 409     409  0.892165         LeakyReLU              0.005004
# 391     391  0.892119              ReLU              0.005653
# 135     135  0.892119              ReLU              0.008760
# 667     667  0.892119              ReLU              0.005755
# 378     378  0.892119         LeakyReLU              0.112381
# 348     348  0.892084         LeakyReLU              0.005303
# 347     347  0.892073              ReLU              0.017219
# 698     698  0.892073              ReLU              0.006826
# 169     169  0.892061              ReLU              0.052498
# 344     344  0.892038              ReLU              0.009126
# 15       15  0.892015             RReLU              0.059659
# 465     465  0.892004         LeakyReLU              0.007939
# 289     289  0.892004         LeakyReLU              0.006922
# 28       28  0.891946              ReLU              0.020564
# 420     420  0.891923              ReLU              0.006281
# 143     143  0.891877             RReLU              0.007162
# 497     497  0.891854              ReLU              0.007464
# 229     229  0.891843              ReLU              0.005541
# 326     326  0.891797              ReLU              0.182971
# 428     428  0.891774              ReLU              0.006169
# 398     398  0.891762              ReLU              0.006116
# 507     507  0.891751              ReLU              0.005005
# 226     226  0.891751         LeakyReLU              0.008619
# 294     294  0.891728         LeakyReLU              0.012382
# 488     488  0.891728              ReLU              0.007749
# 579     579  0.891648              ReLU              0.005006
# 600     600  0.891625              ReLU              0.017275
# 341     341  0.891579         LeakyReLU              0.005793
# 464     464  0.891510              ReLU              0.006538
# 745     745  0.891510              ReLU              0.005428
# 247     247  0.891464         LeakyReLU              0.006459
# 67       67  0.891464             RReLU              0.015505
# 538     538  0.891464         LeakyReLU              0.007170
# 278     278  0.891452              ReLU              0.005873
# 375     375  0.891441              ReLU              0.167086
# 454     454  0.891429              ReLU              0.005010
# 571     571  0.891406         LeakyReLU              0.006398
# 160     160  0.891360         LeakyReLU              0.012656
# 140     140  0.891360             RReLU              0.005062
# 91       91  0.891337              ReLU              0.013216
# 250     250  0.891337         LeakyReLU              0.078113
# 404     404  0.891326         LeakyReLU              0.245174
# 481     481  0.891291             RReLU              0.005003
# 224     224  0.891257         LeakyReLU              0.007618
# 29       29  0.891222              ReLU              0.005893
# 149     149  0.891188              ReLU              0.006681
# 26       26  0.891119              ReLU              0.005900
# 139     139  0.891085             RReLU              0.005304
# 641     641  0.891085              ReLU              0.005371
# 282     282  0.891062              ReLU              0.005697
# 739     739  0.891039              ReLU              0.005006
# 72       72  0.891016              ReLU              0.009207
# 505     505  0.890947              ReLU              0.006984
# 313     313  0.890855              ReLU              0.016029
# 243     243  0.890820         LeakyReLU              0.043698
# 163     163  0.890728              ReLU              0.019613
# 33       33  0.890728              ReLU              0.014530
# 491     491  0.890705         LeakyReLU              0.050432
# 427     427  0.890694         LeakyReLU              0.009838
# 709     709  0.890648              ReLU              0.006480
# 220     220  0.890625              ReLU              0.009608
# 128     128  0.890602              ReLU              0.146577
# 323     323  0.890579         LeakyReLU              0.067992
# 83       83  0.890579              ReLU              0.007200
# 104     104  0.890579         LeakyReLU              0.006753
# 167     167  0.890579              ReLU              0.027906
# 760     760  0.890556              ReLU              0.006167
# 568     568  0.890533              ReLU              0.019585
# 332     332  0.890418         LeakyReLU              0.005985
# 228     228  0.890418             RReLU              0.006081
# 322     322  0.890407              ReLU              0.297545
# 342     342  0.890407         LeakyReLU              0.239785
# 327     327  0.890384         LeakyReLU              0.011421
# 168     168  0.890361              ReLU              0.044307
# 124     124  0.890280              ReLU              0.005861
# 699     699  0.890234              ReLU              0.006274
# 25       25  0.890211              ReLU              0.007218
# 612     612  0.890211              ReLU              0.017701
# 703     703  0.890188              ReLU              0.006718
# 485     485  0.890165         LeakyReLU              0.007129
# 486     486  0.890165              ReLU              0.005828
# 180     180  0.890097              ReLU              0.007474
# 577     577  0.890085              ReLU              0.005788
# 208     208  0.890085              ReLU              0.006688
# 619     619  0.890039              ReLU              0.015986
# 666     666  0.889993              ReLU              0.006246
# 116     116  0.889947              ReLU              0.007660
# 191     191  0.889947         LeakyReLU              0.005381
# 165     165  0.889924              ReLU              0.011273
# 623     623  0.889901             RReLU              0.005474
# 736     736  0.889867              ReLU              0.006911
# 242     242  0.889821         LeakyReLU              0.107348
# 276     276  0.889821              ReLU              0.006540
# 292     292  0.889775         LeakyReLU              0.018332
# 328     328  0.889775              ReLU              0.019702
# 126     126  0.889752              ReLU              0.029090
# 181     181  0.889752              ReLU              0.009134
# 396     396  0.889717              ReLU              0.074875
# 60       60  0.889694              ReLU              0.006495
# 325     325  0.889683         LeakyReLU              0.096250
# 676     676  0.889602              ReLU              0.005446
# 127     127  0.889580              ReLU              0.011711
# 569     569  0.889580         LeakyReLU              0.005044
# 37       37  0.889534              ReLU              0.473133
# 77       77  0.889522              ReLU              0.017872
# 148     148  0.889499              ReLU              0.008522
# 233     233  0.889499         LeakyReLU              0.008945
# 210     210  0.889384             RReLU              0.008606
# 399     399  0.889292         LeakyReLU              0.005446
# 199     199  0.889235             RReLU              0.005433
# 36       36  0.889189              ReLU              0.098934
# 299     299  0.889154         LeakyReLU              0.006322
# 733     733  0.889131              ReLU              0.005036
# 198     198  0.889062         LeakyReLU              0.007651
# 97       97  0.889040         LeakyReLU              0.009549
# 295     295  0.889028         LeakyReLU              0.014981
# 197     197  0.889017         LeakyReLU              0.005884
# 225     225  0.888982         LeakyReLU              0.006858
# 724     724  0.888948              ReLU              0.007001
# 218     218  0.888890         LeakyReLU              0.005455
# 567     567  0.888879         LeakyReLU              0.015836
# 184     184  0.888764              ReLU              0.007782
# 687     687  0.888764              ReLU              0.006025
# 433     433  0.888752         LeakyReLU              0.007658
# 58       58  0.888741              ReLU              0.008971
# 546     546  0.888695         LeakyReLU              0.006897
# 439     439  0.888695              ReLU              0.005036
# 284     284  0.888626              ReLU              0.111091
# 146     146  0.888603         LeakyReLU              0.007479
# 364     364  0.888568             RReLU              0.006160
# 682     682  0.888557              ReLU              0.007104
# 559     559  0.888511         LeakyReLU              0.036457
# 716     716  0.888500              ReLU              0.006476
# 219     219  0.888454              ReLU              0.007275
# 711     711  0.888454              ReLU              0.005892
# 518     518  0.888454             RReLU              0.007753
# 652     652  0.888373              ReLU              0.005063
# 358     358  0.888350         LeakyReLU              0.080953
# 362     362  0.888339         LeakyReLU              0.006659
# 576     576  0.888339              ReLU              0.005060
# 616     616  0.888339              ReLU              0.005009
# 236     236  0.888339         LeakyReLU              0.069113
# 373     373  0.888316              ReLU              0.130251
# 52       52  0.888304              ReLU              0.495590
# 76       76  0.888293              ReLU              0.013477
# 547     547  0.888235         LeakyReLU              0.005418
# 50       50  0.888155         LeakyReLU              0.006593
# 269     269  0.888132              ReLU              0.084138
# 125     125  0.888132              ReLU              0.016163
# 157     157  0.888132         LeakyReLU              0.471383
# 629     629  0.888120             RReLU              0.307774
# 549     549  0.888120             RReLU              0.006127
# 106     106  0.888040              ReLU              0.007163
# 656     656  0.888040              ReLU              0.005650
# 714     714  0.887914              ReLU              0.006827
# 410     410  0.887799         LeakyReLU              0.006804
# 511     511  0.887753             RReLU              0.005824
# 262     262  0.887741         LeakyReLU              0.005681
# 270     270  0.887741              ReLU              0.005085
# 310     310  0.887707              ReLU              0.054627
# 476     476  0.887672         LeakyReLU              0.006029
# 530     530  0.887649         LeakyReLU              0.007262
# 209     209  0.887580              ReLU              0.005885
# 503     503  0.887546              ReLU              0.008433
# 256     256  0.887523         LeakyReLU              0.006690
# 351     351  0.887523              ReLU              0.007528
# 705     705  0.887500              ReLU              0.008680
# 53       53  0.887477              ReLU              0.287998
# 223     223  0.887454         LeakyReLU              0.006247
# 450     450  0.887431         LeakyReLU              0.005677
# 353     353  0.887431             RReLU              0.005895
# 217     217  0.887397              ReLU              0.006509
# 123     123  0.887385              ReLU              0.007062
# 390     390  0.887328         LeakyReLU              0.104591
# 563     563  0.887155             RReLU              0.006831
# 336     336  0.887132             RReLU              0.097503
# 317     317  0.887052              ReLU              0.076604
# 119     119  0.886994         LeakyReLU              0.086154
# 756     756  0.886994              ReLU              0.005943
# 166     166  0.886983              ReLU              0.006720
# 555     555  0.886903             RReLU              0.008479
# 304     304  0.886891         LeakyReLU              0.007389
# 13       13  0.886822             RReLU              0.265199
# 64       64  0.886822              ReLU              0.427956
# 483     483  0.886719         LeakyReLU              0.018755
# 202     202  0.886638              ReLU              0.006503
# 174     174  0.886477             RReLU              0.005660
# 472     472  0.886455         LeakyReLU              0.025646
# 283     283  0.886455              ReLU              0.060103
# 275     275  0.886420              ReLU              0.005407
# 154     154  0.886420              ReLU              0.237832
# 445     445  0.886409              ReLU              0.005575
# 98       98  0.886397         LeakyReLU              0.115058
# 246     246  0.886317         LeakyReLU              0.057363
# 532     532  0.886144         LeakyReLU              0.005577
# 533     533  0.886087         LeakyReLU              0.006724
# 535     535  0.886064         LeakyReLU              0.006165
# 120     120  0.886064              ReLU              0.005014
# 57       57  0.886041              ReLU              0.008342
# 164     164  0.885995              ReLU              0.008155
# 470     470  0.885983         LeakyReLU              0.006728
# 477     477  0.885938              ReLU              0.010226
# 370     370  0.885800         LeakyReLU              0.005125
# 266     266  0.885788              ReLU              0.101964
# 548     548  0.885788         LeakyReLU              0.007767
# 102     102  0.885742         LeakyReLU              0.005027
# 108     108  0.885719              ReLU              0.012355
# 602     602  0.885719              ReLU              0.014000
# 109     109  0.885673             RReLU              0.005403
# 94       94  0.885673         LeakyReLU              0.007692
# 357     357  0.885604              ReLU              0.005010
# 153     153  0.885581              ReLU              0.005031
# 171     171  0.885489             RReLU              0.006204
# 190     190  0.885478         LeakyReLU              0.005028
# 400     400  0.885443              ReLU              0.056827
# 655     655  0.885352              ReLU              0.005047
# 264     264  0.885202              ReLU              0.005951
# 545     545  0.885179         LeakyReLU              0.208279
# 272     272  0.885133              ReLU              0.006067
# 63       63  0.885099              ReLU              0.099655
# 61       61  0.885064              ReLU              0.147618
# 343     343  0.885053              ReLU              0.007240
# 426     426  0.885007              ReLU              0.005005
# 475     475  0.884984              ReLU              0.203949
# 432     432  0.884938              ReLU              0.005916
# 195     195  0.884789         LeakyReLU              0.005030
# 520     520  0.884743         LeakyReLU              0.005013
# 134     134  0.884743              ReLU              0.006760
# 31       31  0.884593              ReLU              0.005085
# 312     312  0.884547              ReLU              0.006455
# 302     302  0.884524         LeakyReLU              0.048224
# 177     177  0.884513              ReLU              0.010214
# 290     290  0.884501         LeakyReLU              0.027539
# 471     471  0.884478              ReLU              0.005457
# 482     482  0.884455              ReLU              0.006538
# 543     543  0.884375         LeakyReLU              0.017283
# 516     516  0.884341             RReLU              0.006397
# 502     502  0.884341         LeakyReLU              0.020972
# 500     500  0.884329         LeakyReLU              0.006485
# 422     422  0.884283              ReLU              0.006986
# 365     365  0.884260         LeakyReLU              0.005563
# 564     564  0.884214              ReLU              0.006255
# 531     531  0.884203         LeakyReLU              0.022996
# 70       70  0.884191              ReLU              0.007331
# 457     457  0.884088         LeakyReLU              0.126340
# 333     333  0.884088              ReLU              0.085534
# 484     484  0.884088              ReLU              0.059021
# 425     425  0.883881         LeakyReLU              0.102708
# 211     211  0.883881              ReLU              0.010557
# 201     201  0.883858              ReLU              0.007987
# 421     421  0.883766         LeakyReLU              0.063086
# 537     537  0.883571             RReLU              0.287417
# 395     395  0.883548         LeakyReLU              0.120561
# 111     111  0.883525              ReLU              0.010248
# 300     300  0.883502         LeakyReLU              0.005016
# 394     394  0.883387             RReLU              0.173916
# 417     417  0.883307         LeakyReLU              0.005634
# 738     738  0.883307              ReLU              0.005009
# 222     222  0.883157         LeakyReLU              0.017201
# 570     570  0.883146              ReLU              0.007470
# 493     493  0.883146         LeakyReLU              0.178531
# 244     244  0.883111         LeakyReLU              0.198124
# 622     622  0.883100              ReLU              0.027450
# 27       27  0.882870              ReLU              0.012328
# 627     627  0.882835              ReLU              0.033027
# 521     521  0.882790         LeakyReLU              0.005018
# 88       88  0.882790         LeakyReLU              0.010764
# 136     136  0.882537              ReLU              0.007737
# 405     405  0.882227         LeakyReLU              0.006708
# 248     248  0.882181         LeakyReLU              0.038537
# 374     374  0.882123         LeakyReLU              0.005451
# 385     385  0.881974         LeakyReLU              0.027171
# 298     298  0.881951         LeakyReLU              0.007106
# 14       14  0.881893             RReLU              0.065392
# 443     443  0.881813              ReLU              0.141484
# 487     487  0.881790         LeakyReLU              0.006437
# 329     329  0.881767         LeakyReLU              0.005506
# 679     679  0.881721              ReLU              0.248004
# 203     203  0.881675              ReLU              0.009623
# 355     355  0.881491         LeakyReLU              0.115926
# 69       69  0.881445              ReLU              0.081495
# 161     161  0.881342              ReLU              0.031355
# 447     447  0.881319              ReLU              0.089937
# 414     414  0.881307         LeakyReLU              0.012593
# 469     469  0.881250              ReLU              0.037459
# 47       47  0.881227              ReLU              0.045025
# 68       68  0.881124              ReLU              0.011543
# 444     444  0.881124         LeakyReLU              0.080935
# 315     315  0.881078              ReLU              0.091581
# 324     324  0.880986              ReLU              0.120132
# 730     730  0.880825              ReLU              0.005316
# 617     617  0.880687              ReLU              0.017034
# 634     634  0.880526              ReLU              0.005698
# 96       96  0.880492         LeakyReLU              0.006314
# 301     301  0.880273         LeakyReLU              0.005746
# 553     553  0.880273         LeakyReLU              0.174234
# 359     359  0.880250              ReLU              0.005382
# 372     372  0.880205         LeakyReLU              0.098300
# 206     206  0.880078              ReLU              0.006072
# 606     606  0.880032              ReLU              0.021240
# 587     587  0.879768              ReLU              0.347551
# 675     675  0.879665              ReLU              0.167087
# 636     636  0.879366              ReLU              0.014859
# 255     255  0.879366         LeakyReLU              0.007594
# 150     150  0.879354             RReLU              0.061797
# 380     380  0.879285             RReLU              0.145402
# 729     729  0.879193              ReLU              0.005510
# 386     386  0.878964              ReLU              0.005004
# 637     637  0.878952              ReLU              0.006150
# 274     274  0.878803              ReLU              0.135540
# 381     381  0.878768         LeakyReLU              0.218872
# 35       35  0.878711              ReLU              0.006784
# 286     286  0.878458         LeakyReLU              0.005019
# 40       40  0.877711              ReLU              0.025317
# 39       39  0.877654              ReLU              0.019059
# 544     544  0.877585             RReLU              0.152495
# 431     431  0.877562         LeakyReLU              0.007036
# 43       43  0.877252              ReLU              0.005465
# 241     241  0.877125         LeakyReLU              0.094111
# 501     501  0.876988              ReLU              0.432737
# 539     539  0.876953         LeakyReLU              0.005755
# 117     117  0.876907              ReLU              0.006261
# 309     309  0.876907         LeakyReLU              0.014088
# 759     759  0.876494              ReLU              0.005640
# 89       89  0.876287         LeakyReLU              0.056234
# 438     438  0.876195             RReLU              0.112256
# 411     411  0.875149         LeakyReLU              0.048170
# 387     387  0.875069              ReLU              0.081254
# 335     335  0.874989              ReLU              0.005076
# 318     318  0.874540         LeakyReLU              0.088367
# 162     162  0.874437              ReLU              0.018272
# 684     684  0.874173              ReLU              0.007833
# 418     418  0.874150         LeakyReLU              0.324472
# 285     285  0.873656              ReLU              0.198166
# 392     392  0.873288         LeakyReLU              0.030199
# 259     259  0.873116         LeakyReLU              0.014289
# 573     573  0.872622             RReLU              0.136300
# 17       17  0.872461             RReLU              0.070278
# 669     669  0.872346              ReLU              0.005496
# 384     384  0.872070              ReLU              0.144483
# 55       55  0.871703              ReLU              0.364030
# 635     635  0.871312             RReLU              0.041572
# 490     490  0.871071              ReLU              0.013035
# 609     609  0.871002              ReLU              0.019055
# 44       44  0.870841              ReLU              0.007871
# 339     339  0.870462              ReLU              0.063241
# 249     249  0.870117         LeakyReLU              0.065049
# 594     594  0.869060              ReLU              0.005398
# 345     345  0.869049              ReLU              0.007807
# 12       12  0.868233             RReLU              0.142800
# 34       34  0.867670              ReLU              0.009983
# 334     334  0.867452         LeakyReLU              0.013338
# 8         8  0.866556         LeakyReLU              0.268936
# 267     267  0.866234              ReLU              0.129881
# 388     388  0.864867         LeakyReLU              0.195240
# 258     258  0.864177             RReLU              0.120475
# 448     448  0.864166         LeakyReLU              0.011573
# 296     296  0.863959         LeakyReLU              0.069281
# 142     142  0.859318             RReLU              0.005727
# 459     459  0.858100         LeakyReLU              0.096965
# 186     186  0.857893              ReLU              0.023736
# 550     550  0.857686         LeakyReLU              0.005897
# 557     557  0.857583         LeakyReLU              0.007283
# 642     642  0.856928             RReLU              0.189627
# 277     277  0.856836              ReLU              0.259098
# 268     268  0.854745              ReLU              0.159319
# 20       20  0.853745              ReLU              0.035271
# 383     383  0.853539         LeakyReLU              0.186879
# 130     130  0.853102              ReLU              0.014240
# 90       90  0.852413         LeakyReLU              0.045324
# 371     371  0.852045              ReLU              0.005051
# 479     479  0.850770              ReLU              0.008217
# 442     442  0.850689         LeakyReLU              0.367095
# 75       75  0.848116              ReLU              0.005819
# 54       54  0.847656              ReLU              0.208547
# 129     129  0.843635         LeakyReLU              0.180629
# 360     360  0.843601         LeakyReLU              0.007078
# 316     316  0.840981         LeakyReLU              0.106094
# 100     100  0.839568         LeakyReLU              0.073311
# 41       41  0.839361              ReLU              0.011104
# 280     280  0.837695              ReLU              0.005413
# 2         2  0.836569             RReLU              0.122353
# 271     271  0.835340              ReLU              0.158758
# 16       16  0.835340             RReLU              0.031854
# 610     610  0.834249              ReLU              0.019376
# 200     200  0.829366         LeakyReLU              0.128077
# 79       79  0.820726              ReLU              0.009812
# 11       11  0.811397             RReLU              0.104709
# 46       46  0.809042              ReLU              0.211687
# 758     758  0.804688              ReLU              0.006633
# 700     700  0.802309              ReLU              0.007920
# 654     654  0.797783              ReLU              0.413629
# 147     147  0.796737              ReLU              0.038700
# 1         1  0.796174         LeakyReLU              0.330047
# 5         5  0.793635             RReLU              0.409266
# 3         3  0.793015         LeakyReLU              0.008438
# 354     354  0.791245         LeakyReLU              0.005059
# 237     237  0.791199         LeakyReLU              0.175300
# 731     731  0.789120              ReLU              0.005118
# 80       80  0.788971             RReLU              0.011059
# 671     671  0.787293              ReLU              0.006646
# 59       59  0.785604         LeakyReLU              0.012381
# 6         6  0.784065             RReLU              0.021113
# ...
# 169             batchnorm  COMPLETE
# 344             batchnorm  COMPLETE
# 15              batchnorm  COMPLETE
# 465             batchnorm  COMPLETE
# 289             batchnorm  COMPLETE
# 28              batchnorm  COMPLETE
# 420             batchnorm  COMPLETE
# 143             batchnorm  COMPLETE
# 497             batchnorm  COMPLETE
# 229             batchnorm  COMPLETE
# 326             batchnorm  COMPLETE
# 428             batchnorm  COMPLETE
# 398             batchnorm  COMPLETE
# 507             batchnorm  COMPLETE
# 226             batchnorm  COMPLETE
# 294             batchnorm  COMPLETE
# 488             batchnorm  COMPLETE
# 579             batchnorm  COMPLETE
# 600             batchnorm  COMPLETE
# 341             batchnorm  COMPLETE
# 464             batchnorm  COMPLETE
# 745             batchnorm  COMPLETE
# 247             batchnorm  COMPLETE
# 67              batchnorm  COMPLETE
# 538             batchnorm  COMPLETE
# 278             batchnorm  COMPLETE
# 375             batchnorm  COMPLETE
# 454             batchnorm  COMPLETE
# 571             batchnorm  COMPLETE
# 160             batchnorm  COMPLETE
# 140             batchnorm  COMPLETE
# 91              batchnorm  COMPLETE
# 250             batchnorm  COMPLETE
# 404             batchnorm  COMPLETE
# 481             batchnorm  COMPLETE
# 224             batchnorm  COMPLETE
# 29              batchnorm  COMPLETE
# 149             batchnorm  COMPLETE
# 26              batchnorm  COMPLETE
# 139             batchnorm  COMPLETE
# 641             batchnorm  COMPLETE
# 282             batchnorm  COMPLETE
# 739             batchnorm  COMPLETE
# 72              batchnorm  COMPLETE
# 505             batchnorm  COMPLETE
# 313             batchnorm  COMPLETE
# 243             batchnorm  COMPLETE
# 163             batchnorm  COMPLETE
# 33              batchnorm  COMPLETE
# 491             batchnorm  COMPLETE
# 427             batchnorm  COMPLETE
# 709             batchnorm  COMPLETE
# 220             batchnorm  COMPLETE
# 128             batchnorm  COMPLETE
# 323             batchnorm  COMPLETE
# 83              batchnorm  COMPLETE
# 104             batchnorm  COMPLETE
# 167             batchnorm  COMPLETE
# 760             batchnorm  COMPLETE
# 568             batchnorm  COMPLETE
# 332             batchnorm  COMPLETE
# 228             batchnorm  COMPLETE
# 322             batchnorm  COMPLETE
# 342             batchnorm  COMPLETE
# 327             batchnorm  COMPLETE
# 168             batchnorm  COMPLETE
# 124             batchnorm  COMPLETE
# 699             batchnorm  COMPLETE
# 25              batchnorm  COMPLETE
# 612             batchnorm  COMPLETE
# 703             batchnorm  COMPLETE
# 485             batchnorm  COMPLETE
# 486             batchnorm  COMPLETE
# 180             batchnorm  COMPLETE
# 577             batchnorm  COMPLETE
# 208             batchnorm  COMPLETE
# 619             batchnorm  COMPLETE
# 666             batchnorm  COMPLETE
# 116             batchnorm  COMPLETE
# 191             batchnorm  COMPLETE
# 165             batchnorm  COMPLETE
# 623             batchnorm  COMPLETE
# 736             batchnorm  COMPLETE
# 242             batchnorm  COMPLETE
# 276             batchnorm  COMPLETE
# 292             batchnorm  COMPLETE
# 328             batchnorm  COMPLETE
# 126             batchnorm  COMPLETE
# 181             batchnorm  COMPLETE
# 396             batchnorm  COMPLETE
# 60              batchnorm  COMPLETE
# 325             batchnorm  COMPLETE
# 676             batchnorm  COMPLETE
# 127             batchnorm  COMPLETE
# 569             batchnorm  COMPLETE
# 37              batchnorm  COMPLETE
# 77              batchnorm  COMPLETE
# 148             batchnorm  COMPLETE
# 233             batchnorm  COMPLETE
# 210             batchnorm  COMPLETE
# 399             batchnorm  COMPLETE
# 199             batchnorm  COMPLETE
# 36              batchnorm  COMPLETE
# 299             batchnorm  COMPLETE
# 733             batchnorm  COMPLETE
# 198             batchnorm  COMPLETE
# 97              batchnorm  COMPLETE
# 295             batchnorm  COMPLETE
# 197             batchnorm  COMPLETE
# 225             batchnorm  COMPLETE
# 724             batchnorm  COMPLETE
# 218             batchnorm  COMPLETE
# 567             batchnorm  COMPLETE
# 184             batchnorm  COMPLETE
# 687             batchnorm  COMPLETE
# 433             batchnorm  COMPLETE
# 58              batchnorm  COMPLETE
# 546             batchnorm  COMPLETE
# 439             batchnorm  COMPLETE
# 284             batchnorm  COMPLETE
# 146             batchnorm  COMPLETE
# 364             batchnorm  COMPLETE
# 682             batchnorm  COMPLETE
# 559             batchnorm  COMPLETE
# 716             batchnorm  COMPLETE
# 219             batchnorm  COMPLETE
# 711             batchnorm  COMPLETE
# 518             batchnorm  COMPLETE
# 652             batchnorm  COMPLETE
# 358             batchnorm  COMPLETE
# 362             batchnorm  COMPLETE
# 576             batchnorm  COMPLETE
# 616             batchnorm  COMPLETE
# 236             batchnorm  COMPLETE
# 373             batchnorm  COMPLETE
# 52              batchnorm  COMPLETE
# 76              batchnorm  COMPLETE
# 547             batchnorm  COMPLETE
# 50              batchnorm  COMPLETE
# 269             batchnorm  COMPLETE
# 125             batchnorm  COMPLETE
# 157             batchnorm  COMPLETE
# 629             batchnorm  COMPLETE
# 549             batchnorm  COMPLETE
# 106             batchnorm  COMPLETE
# 656             batchnorm  COMPLETE
# 714             batchnorm  COMPLETE
# 410             batchnorm  COMPLETE
# 511             batchnorm  COMPLETE
# 262             batchnorm  COMPLETE
# 270             batchnorm  COMPLETE
# 310             batchnorm  COMPLETE
# 476             batchnorm  COMPLETE
# 530             batchnorm  COMPLETE
# 209             batchnorm  COMPLETE
# 503             batchnorm  COMPLETE
# 256             batchnorm  COMPLETE
# 351             batchnorm  COMPLETE
# 705             batchnorm  COMPLETE
# 53              batchnorm  COMPLETE
# 223             batchnorm  COMPLETE
# 450             batchnorm  COMPLETE
# 353             batchnorm  COMPLETE
# 217             batchnorm  COMPLETE
# 123             batchnorm  COMPLETE
# 390             batchnorm  COMPLETE
# 563             batchnorm  COMPLETE
# 336             batchnorm  COMPLETE
# 317             batchnorm  COMPLETE
# 119             batchnorm  COMPLETE
# 756             batchnorm  COMPLETE
# 166             batchnorm  COMPLETE
# 555             batchnorm  COMPLETE
# 304             batchnorm  COMPLETE
# 13              batchnorm  COMPLETE
# 64              batchnorm  COMPLETE
# 483             batchnorm  COMPLETE
# 202             batchnorm  COMPLETE
# 174             batchnorm  COMPLETE
# 472             batchnorm  COMPLETE
# 283             batchnorm  COMPLETE
# 275             batchnorm  COMPLETE
# 154             batchnorm  COMPLETE
# 445             batchnorm  COMPLETE
# 98              batchnorm  COMPLETE
# 246             batchnorm  COMPLETE
# 532             batchnorm  COMPLETE
# 533             batchnorm  COMPLETE
# 535             batchnorm  COMPLETE
# 120             batchnorm  COMPLETE
# 57              batchnorm  COMPLETE
# 164             batchnorm  COMPLETE
# 470             batchnorm  COMPLETE
# 477             batchnorm  COMPLETE
# 370             batchnorm  COMPLETE
# 266             batchnorm  COMPLETE
# 548             batchnorm  COMPLETE
# 102             batchnorm  COMPLETE
# 108             batchnorm  COMPLETE
# 602             batchnorm  COMPLETE
# 109             batchnorm  COMPLETE
# 94              batchnorm  COMPLETE
# 357             batchnorm  COMPLETE
# 153             batchnorm  COMPLETE
# 171             batchnorm  COMPLETE
# 190             batchnorm  COMPLETE
# 400             batchnorm  COMPLETE
# 655             batchnorm  COMPLETE
# 264             batchnorm  COMPLETE
# 545             batchnorm  COMPLETE
# 272             batchnorm  COMPLETE
# 63              batchnorm  COMPLETE
# 61              batchnorm  COMPLETE
# 343             batchnorm  COMPLETE
# 426             batchnorm  COMPLETE
# 475             batchnorm  COMPLETE
# 432             batchnorm  COMPLETE
# 195             batchnorm  COMPLETE
# 520             batchnorm  COMPLETE
# 134             batchnorm  COMPLETE
# 31              batchnorm  COMPLETE
# 312             batchnorm  COMPLETE
# 302             batchnorm  COMPLETE
# 177             batchnorm  COMPLETE
# 290             batchnorm  COMPLETE
# 471             batchnorm  COMPLETE
# 482             batchnorm  COMPLETE
# 543             batchnorm  COMPLETE
# 516             batchnorm  COMPLETE
# 502             batchnorm  COMPLETE
# 500             batchnorm  COMPLETE
# 422             batchnorm  COMPLETE
# 365             batchnorm  COMPLETE
# 564             batchnorm  COMPLETE
# 531             batchnorm  COMPLETE
# 70              batchnorm  COMPLETE
# 457             batchnorm  COMPLETE
# 333             batchnorm  COMPLETE
# 484             batchnorm  COMPLETE
# 425             batchnorm  COMPLETE
# 211             batchnorm  COMPLETE
# 201             batchnorm  COMPLETE
# 421             batchnorm  COMPLETE
# 537             batchnorm  COMPLETE
# 395             batchnorm  COMPLETE
# 111             batchnorm  COMPLETE
# 300             batchnorm  COMPLETE
# 394             batchnorm  COMPLETE
# 417             batchnorm  COMPLETE
# 738             batchnorm  COMPLETE
# 222             batchnorm  COMPLETE
# 570             batchnorm  COMPLETE
# 493             batchnorm  COMPLETE
# 244             batchnorm  COMPLETE
# 622             batchnorm  COMPLETE
# 27              batchnorm  COMPLETE
# 627             batchnorm  COMPLETE
# 521             batchnorm  COMPLETE
# 88              batchnorm  COMPLETE
# 136             batchnorm  COMPLETE
# 405             batchnorm  COMPLETE
# 248             batchnorm  COMPLETE
# 374             batchnorm  COMPLETE
# 385             batchnorm  COMPLETE
# 298             batchnorm  COMPLETE
# 14              batchnorm  COMPLETE
# 443             batchnorm  COMPLETE
# 487             batchnorm  COMPLETE
# 329             batchnorm  COMPLETE
# 679             batchnorm  COMPLETE
# 203             batchnorm  COMPLETE
# 355             batchnorm  COMPLETE
# 69              batchnorm  COMPLETE
# 161             batchnorm  COMPLETE
# 447             batchnorm  COMPLETE
# 414             batchnorm  COMPLETE
# 469             batchnorm  COMPLETE
# 47              batchnorm  COMPLETE
# 68              batchnorm  COMPLETE
# 444             batchnorm  COMPLETE
# 315             batchnorm  COMPLETE
# 324             batchnorm  COMPLETE
# 730             batchnorm  COMPLETE
# 617             batchnorm  COMPLETE
# 634             batchnorm  COMPLETE
# 96              batchnorm  COMPLETE
# 301             batchnorm  COMPLETE
# 553             batchnorm  COMPLETE
# 359             batchnorm  COMPLETE
# 372             batchnorm  COMPLETE
# 206             batchnorm  COMPLETE
# 606             batchnorm  COMPLETE
# 587             batchnorm  COMPLETE
# 675             batchnorm  COMPLETE
# 636             batchnorm  COMPLETE
# 255             batchnorm  COMPLETE
# 150             batchnorm  COMPLETE
# 380             batchnorm  COMPLETE
# 729             batchnorm  COMPLETE
# 386             batchnorm  COMPLETE
# 637             batchnorm  COMPLETE
# 274             batchnorm  COMPLETE
# 381             batchnorm  COMPLETE
# 35              batchnorm  COMPLETE
# 286             batchnorm  COMPLETE
# 40              batchnorm  COMPLETE
# 39              batchnorm  COMPLETE
# 544             batchnorm  COMPLETE
# 431             batchnorm  COMPLETE
# 43              batchnorm  COMPLETE
# 241             batchnorm  COMPLETE
# 501             batchnorm  COMPLETE
# 539             batchnorm  COMPLETE
# 117             batchnorm  COMPLETE
# 309             batchnorm  COMPLETE
# 759             batchnorm  COMPLETE
# 89              batchnorm  COMPLETE
# 438             batchnorm  COMPLETE
# 411             batchnorm  COMPLETE
# 387             batchnorm  COMPLETE
# 335             batchnorm  COMPLETE
# 318             batchnorm  COMPLETE
# 162             batchnorm  COMPLETE
# 684             batchnorm  COMPLETE
# 418             batchnorm  COMPLETE
# 285             batchnorm  COMPLETE
# 392             batchnorm  COMPLETE
# 259             batchnorm  COMPLETE
# 573             batchnorm  COMPLETE
# 17              batchnorm  COMPLETE
# 669             batchnorm  COMPLETE
# 384             batchnorm  COMPLETE
# 55              batchnorm  COMPLETE
# 635             batchnorm  COMPLETE
# 490             batchnorm  COMPLETE
# 609             batchnorm  COMPLETE
# 44              batchnorm  COMPLETE
# 339             batchnorm  COMPLETE
# 249             batchnorm  COMPLETE
# 594             batchnorm  COMPLETE
# 345             batchnorm  COMPLETE
# 12              batchnorm  COMPLETE
# 34              batchnorm  COMPLETE
# 334             batchnorm  COMPLETE
# 8                 dropout  COMPLETE
# 267               dropout  COMPLETE
# 388             batchnorm  COMPLETE
# 258             batchnorm  COMPLETE
# 448             batchnorm  COMPLETE
# 296               dropout  COMPLETE
# 142             batchnorm  COMPLETE
# 459             batchnorm  COMPLETE
# 186             batchnorm  COMPLETE
# 550             batchnorm  COMPLETE
# 557             batchnorm  COMPLETE
# 642               dropout  COMPLETE
# 277             batchnorm  COMPLETE
# 268             batchnorm  COMPLETE
# 20              batchnorm  COMPLETE
# 383               dropout  COMPLETE
# 130             batchnorm  COMPLETE
# 90              batchnorm  COMPLETE
# 371             batchnorm  COMPLETE
# 479             batchnorm  COMPLETE
# 442             batchnorm  COMPLETE
# 75              batchnorm  COMPLETE
# 54              batchnorm  COMPLETE
# 129             batchnorm  COMPLETE
# 360             batchnorm  COMPLETE
# 316             batchnorm  COMPLETE
# 100             batchnorm  COMPLETE
# 41              batchnorm  COMPLETE
# 280             batchnorm  COMPLETE
# 2                 dropout  COMPLETE
# 271             batchnorm  COMPLETE
# 16              batchnorm  COMPLETE
# 610             batchnorm  COMPLETE
# 200             batchnorm  COMPLETE
# 79              batchnorm  COMPLETE
# 11                dropout  COMPLETE
# 46              batchnorm  COMPLETE
# 758               dropout  COMPLETE
# 700               dropout  COMPLETE
# 654             batchnorm  COMPLETE
# 147             batchnorm  COMPLETE
# 1                 dropout  COMPLETE
# 5               batchnorm  COMPLETE
# 3                 dropout  COMPLETE
# 354               dropout  COMPLETE
# 237             batchnorm  COMPLETE
# 731               dropout  COMPLETE
# 80                dropout  COMPLETE
# 671               dropout  COMPLETE
# 59                dropout  COMPLETE
# 6                 dropout  COMPLETE
# 412               dropout  COMPLETE
# 7                 dropout  COMPLETE
# 462             batchnorm  COMPLETE
# 389             batchnorm  COMPLETE
# 10              batchnorm  COMPLETE
# 556               dropout  COMPLETE
# 176               dropout  COMPLETE
# 468               dropout  COMPLETE
# 526               dropout  COMPLETE
# 583               dropout  COMPLETE
# 440               dropout  COMPLETE
# 496               dropout  COMPLETE
# 613               dropout  COMPLETE
# 419             batchnorm  COMPLETE
# 638             batchnorm  COMPLETE
# 107               dropout  COMPLETE
# 429             batchnorm  COMPLETE
# 227               dropout  COMPLETE
# 137               dropout  COMPLETE
# 48                dropout  COMPLETE
# 0                 dropout  COMPLETE
# 45                dropout  COMPLETE
# 9                 dropout  COMPLETE
# 330               dropout  COMPLETE
# 4                 dropout  COMPLETE
# 540             batchnorm      FAIL

# %% [markdown]
# Выводы:
# * Лучшая точность получилась около 0.9
# * Лучшей функцией активации оказалася ReLU; LeakyReLU - чуть хуже, RReLU хороших результатов не дал
# * Лучшим оптимизатором - SGD
# * Лучшая регуляризация - batchnorm
# * Лучшие результаты были достигнуты сетями с небольшим количеством слоев (3-4), есть подозрение что на сетки с большим количеством слоев надо больше, чем 30 эпох.
# * Хороший результат дает увеличение количества нейронов в первом скрытом слое, по сравнению с входами
# * Чем меньше learning rate (за редкими, особо удачными исключениями) - тем лучше обучилась модель

# %%
df.loc[599]
# Out:
# number                         599
# value                     0.903941
# params_activation             ReLU
# params_learning_rate     0.0178311
# params_max_features           1419
# params_n_layers                  4
# params_optimizer               SGD
# params_regularization    batchnorm
# state                     COMPLETE
# Name: 599, dtype: object

# %% [markdown]
# ----------------------------------------------------------------------------------------------------
# TEST RESULTS
# {'test_loss': tensor(0.3392, device='cuda:0'), 'test_accuracy': 0.8962890625}
# ----------------------------------------------------------------------------------------------------
